# %% [markdown]
# # Analyzing Golang binaries with Radare2

# %% [markdown]
# ### Load environment

# %%
try:
    # if using jupyter within cutter, use the following. This will use the current active binary.
    import cutter
    # we'll assign cutter to variable r2 to be consistent with r2pipe
    r2 = cutter
    print("[+] loaded Cutter binary")
except ModuleNotFoundError as exc:
    # using r2pipe to open a binary
    import r2pipe
    r2 = r2pipe.open("test")
    print("[+] loaded binary")
# Out:
# [+] loaded Cutter binary

# %% [markdown]
# ### Start analysis

# %%
# %time r2.cmd('aaa')

# %% [markdown]
# ### find .goclntab section

# %%
import json

sections = {}

for section in json.loads(r2.cmd("iSj")):
    name = section.get('name')
    sections[name] = { 'name': name, 'size': section.get('size'), 'vaddr': section.get('vaddr')}

# %%
size = sections['.gopclntab'].get('size')
vaddr = sections['.gopclntab'].get('vaddr')

# not efficient, takes a long time. Better will be to retrieve directly from 
# raw file.
data = bytes(json.loads(r2.cmd("pxj {} @ {}".format(size, vaddr))))

print ("[+] .gopclntab section found: size={} vaddr={}".format(size, vaddr))
# Out:
# [+] .gopclntab section found: size=448041 vaddr=5024768

# %%
import binascii
import struct

def read_var_int(p): 
    result = 0
    shift = 0
    while True:
        b = p[0]
        p = p[1:]

        result |= ((b & 0x7F) << shift)
        if not (b & 0x80):
            break

        shift += 7

    return p, result

def pcValue(p):
    pc = 0
    val = -1

    j = 0
    while True:
        p, uvdelta = read_var_int(p)
        if uvdelta ==0:
            break 

        val += decodeZigZag32(uvdelta)
    
        p, pcdelta = read_var_int(p)
        pc+=(pcdelta)

        yield (val, pc)
        
        j+=1

# https://gist.github.com/matteobertozzi/1521947
def encodeZigZag32(n): return (n << 1) ^ (n >> 31)
def encodeZigZag64(n): return (n << 1) ^ (n >> 63)
def decodeZigZag32(n): return (n >> 1) ^ -(n & 1)
def decodeZigZag64(n): return (n >> 1) ^ -(n & 1)

# %%
import binascii
import struct

# https://docs.google.com/document/d/1lyPIbmsYbXnpNj57a261hgOYVpNRcgydurVQIyZOz_o/pub
offset = 0 

magic, = struct.unpack_from("I", s, offset)
offset += 4

if magic != 0xfffffffb:
    print("[!] Magic incorrect for .gopclnt")
    raise Exception("Magic incorrect")
    
quantum, uintptr_size, = struct.unpack_from("xxbb", s, offset)
offset += 4

# https://docs.google.com/document/d/1lyPIbmsYbXnpNj57a261hgOYVpNRcgydurVQIyZOz_o/pub
table_size, = struct.unpack_from("q", s, offset)
offset += 8

# Retrieve path from file table. The file table is located at table_size
def file_table(index):
    file_table_offset, = struct.unpack_from("i", s, 4 + 4 + 8 + table_size * 16 + 8)

    file_table_size, = struct.unpack_from("i", s, file_table_offset)

    name_offset, = struct.unpack_from("i", s, file_table_offset + index * 4)
    name = s[name_offset:]
    name= name[:name.index(b"\0")].decode('utf-8')
    return name

# https://golang.org/src/cmd/internal/objfile/goobj.go
for i in range(0, table_size):
    pc, func_offset, = struct.unpack_from("qq", s, offset)

    offset += struct.calcsize("qq")
            
    entry, name_offset, args, frame, pcsp, pcfile, pcln, nfuncdata, npcdata, = struct.unpack_from("qiiiiiiii", s, func_offset)
    name = s[name_offset:]
    name= name[:name.index(b"\0")].decode('utf-8')
    
    if not name.startswith('main.'):
        continue        

    print("[ ] name={} entry={:x} args={:x} frame={:x} pcsp={:x} pcfile={:x} pcln={:x} nfuncdata={:x} npcdata={:x}".format(name, entry, args, frame, pcsp, pcfile, pcln, nfuncdata, npcdata))

    if pcfile == 0:
        continue

    def line2path(addr):
        for (val, pc) in pcValue(s[pcfile:]):
            if addr < pc:
                return file_table(val)

        return None

    addr = 0
    for (val, pc) in pcValue(s[pcln:]):
        path = line2path(pc)
        if not path:
            continue
            
        r2.cmd('CCu {}:{} @ 0x{:x}'.format(path, val, entry + addr))
        print('[ ] path={}:{} addr=0x{:x}'.format(line2path(pc), val, entry + addr))
        addr = pc
# Out:
# [ ] name=main.main entry=485040 args=0 frame=0 pcsp=6afcb pcfile=6afd4 pcln=6afd8 nfuncdata=3 npcdata=4
# [ ] path=/Users/remco/Projects/sans/test.go:5 addr=0x485040
# [ ] path=/Users/remco/Projects/sans/test.go:6 addr=0x48505d
# [ ] path=/Users/remco/Projects/sans/test.go:7 addr=0x48509d
# [ ] name=main.init entry=4850b0 args=0 frame=0 pcsp=6b063 pcfile=6b06e pcln=6b071 nfuncdata=3 npcdata=4

# %% [markdown]
# ### Print all source files

# %%
file_table_offset, = struct.unpack_from("i", s, 4 + 4 + 8 + table_size * 16 + 8)

file_table_size, = struct.unpack_from("i", s, file_table_offset)

for i in range(1, file_table_size):
    name_offset, = struct.unpack_from("i", s, file_table_offset + i * 4)
    name = s[name_offset:]
    name= name[:name.index(b"\0")]
    name = name.decode('utf-8')
    print("[ ] index={} path={}".format(i, name))
    continue
# Out:
# [ ] index=1 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/cpu/cpu.go
# [ ] index=2 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/cpu/cpu_x86.go
# [ ] index=3 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/cpu/cpu_x86.s
# [ ] index=4 path=<autogenerated>
# [ ] index=5 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/atomic/value.go
# [ ] index=6 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/atomic/asm.s
# [ ] index=7 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/internal/atomic/asm_amd64.s
# [ ] index=8 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/bytealg/index_amd64.go
# [ ] index=9 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/bytealg/compare_amd64.s
# [ ] index=10 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/bytealg/equal_amd64.s
# [ ] index=11 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/bytealg/indexbyte_amd64.s
# [ ] index=12 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/alg.go
# [ ] index=13 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/stubs.go
# [ ] index=14 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/typekind.go
# [ ] index=15 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/atomic_pointer.go
# [ ] index=16 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mwbbuf.go
# [ ] index=17 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cgo_mmap.go
# [ ] index=18 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cgo_sigaction.go
# [ ] index=19 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cgocall.go
# [ ] index=20 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/symtab.go
# [ ] index=21 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cgocheck.go
# [ ] index=22 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mheap.go
# [ ] index=23 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mbitmap.go
# [ ] index=24 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/chan.go
# [ ] index=25 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/slice.go
# [ ] index=26 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/runtime2.go
# [ ] index=27 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cpuflags_amd64.go
# [ ] index=28 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/cpuprof.go
# [ ] index=29 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/proc.go
# [ ] index=30 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/debug.go
# [ ] index=31 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/debugcall.go
# [ ] index=32 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/env_posix.go
# [ ] index=33 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/error.go
# [ ] index=34 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/extern.go
# [ ] index=35 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/float.go
# [ ] index=36 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/hash64.go
# [ ] index=37 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/unaligned1.go
# [ ] index=38 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/iface.go
# [ ] index=39 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/type.go
# [ ] index=40 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/lfstack.go
# [ ] index=41 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/lfstack_64bit.go
# [ ] index=42 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/lock_futex.go
# [ ] index=43 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/malloc.go
# [ ] index=44 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mfixalloc.go
# [ ] index=45 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/runtime1.go
# [ ] index=46 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgc.go
# [ ] index=47 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/fastlog2.go
# [ ] index=48 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/map.go
# [ ] index=49 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/msize.go
# [ ] index=50 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/map_fast32.go
# [ ] index=51 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/map_fast64.go
# [ ] index=52 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/map_faststr.go
# [ ] index=53 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mbarrier.go
# [ ] index=54 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mcache.go
# [ ] index=55 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mcentral.go
# [ ] index=56 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mem_linux.go
# [ ] index=57 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mfinal.go
# [ ] index=58 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgcwork.go
# [ ] index=59 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgcsweep.go
# [ ] index=60 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgclarge.go
# [ ] index=61 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgcmark.go
# [ ] index=62 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mgcsweepbuf.go
# [ ] index=63 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mprof.go
# [ ] index=64 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/mstats.go
# [ ] index=65 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/netpoll.go
# [ ] index=66 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/netpoll_epoll.go
# [ ] index=67 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/os_linux.go
# [ ] index=68 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/defs_linux_amd64.go
# [ ] index=69 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/os_linux_generic.go
# [ ] index=70 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/panic.go
# [ ] index=71 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/string.go
# [ ] index=72 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/signal_unix.go
# [ ] index=73 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/print.go
# [ ] index=74 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/traceback.go
# [ ] index=75 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/sys_x86.go
# [ ] index=76 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/stack.go
# [ ] index=77 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/profbuf.go
# [ ] index=78 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/runtime.go
# [ ] index=79 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/rwmutex.go
# [ ] index=80 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/sema.go
# [ ] index=81 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/signal_amd64x.go
# [ ] index=82 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/signal_linux_amd64.go
# [ ] index=83 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/signal_sighandler.go
# [ ] index=84 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/sigqueue.go
# [ ] index=85 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/internal/sys/intrinsics.go
# [ ] index=86 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/time.go
# [ ] index=87 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/timestub.go
# [ ] index=88 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/trace.go
# [ ] index=89 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/utf8.go
# [ ] index=90 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/vdso_linux.go
# [ ] index=91 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/write_err.go
# [ ] index=92 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/select.go
# [ ] index=93 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/asm.s
# [ ] index=94 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/asm_amd64.s
# [ ] index=95 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/duff_amd64.s
# [ ] index=96 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/memclr_amd64.s
# [ ] index=97 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/memmove_amd64.s
# [ ] index=98 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/rt0_linux_amd64.s
# [ ] index=99 path=/usr/local/Cellar/go/1.11.5/libexec/src/runtime/sys_linux_amd64.s
# [ ] index=100 path=/usr/local/Cellar/go/1.11.5/libexec/src/math/exp_asm.go
# [ ] index=101 path=/usr/local/Cellar/go/1.11.5/libexec/src/errors/errors.go
# [ ] index=102 path=/usr/local/Cellar/go/1.11.5/libexec/src/unicode/utf8/utf8.go
# [ ] index=103 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/decimal.go
# [ ] index=104 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/extfloat.go
# [ ] index=105 path=/usr/local/Cellar/go/1.11.5/libexec/src/math/bits/bits.go
# [ ] index=106 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/ftoa.go
# [ ] index=107 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/itoa.go
# [ ] index=108 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/quote.go
# [ ] index=109 path=/usr/local/Cellar/go/1.11.5/libexec/src/strconv/atoi.go
# [ ] index=110 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/map.go
# [ ] index=111 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/mutex.go
# [ ] index=112 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/once.go
# [ ] index=113 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/pool.go
# [ ] index=114 path=/usr/local/Cellar/go/1.11.5/libexec/src/sync/runtime.go
# [ ] index=115 path=/usr/local/Cellar/go/1.11.5/libexec/src/io/io.go
# [ ] index=116 path=/usr/local/Cellar/go/1.11.5/libexec/src/io/pipe.go
# [ ] index=117 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/exec_unix.go
# [ ] index=118 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/str.go
# [ ] index=119 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/syscall.go
# [ ] index=120 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/syscall_linux.go
# [ ] index=121 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/syscall_unix.go
# [ ] index=122 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/zsyscall_linux_amd64.go
# [ ] index=123 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/env_unix.go
# [ ] index=124 path=/usr/local/Cellar/go/1.11.5/libexec/src/syscall/asm_linux_amd64.s
# [ ] index=125 path=/usr/local/Cellar/go/1.11.5/libexec/src/time/format.go
# [ ] index=126 path=/usr/local/Cellar/go/1.11.5/libexec/src/time/zoneinfo.go
# [ ] index=127 path=/usr/local/Cellar/go/1.11.5/libexec/src/time/zoneinfo_read.go
# [ ] index=128 path=/usr/local/Cellar/go/1.11.5/libexec/src/time/zoneinfo_unix.go
# [ ] index=129 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/poll/fd.go
# [ ] index=130 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/poll/fd_mutex.go
# [ ] index=131 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/poll/fd_poll_runtime.go
# [ ] index=132 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/poll/fd_unix.go
# [ ] index=133 path=/usr/local/Cellar/go/1.11.5/libexec/src/internal/syscall/unix/nonblocking.go
# [ ] index=134 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/error.go
# [ ] index=135 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/file.go
# [ ] index=136 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/file_posix.go
# [ ] index=137 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/file_unix.go
# [ ] index=138 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/proc.go
# [ ] index=139 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/executable_procfs.go
# [ ] index=140 path=/usr/local/Cellar/go/1.11.5/libexec/src/os/exec_unix.go
# [ ] index=141 path=/usr/local/Cellar/go/1.11.5/libexec/src/unicode/tables.go
# [ ] index=142 path=/usr/local/Cellar/go/1.11.5/libexec/src/reflect/makefunc.go
# [ ] index=143 path=/usr/local/Cellar/go/1.11.5/libexec/src/reflect/type.go
# [ ] index=144 path=/usr/local/Cellar/go/1.11.5/libexec/src/reflect/value.go
# [ ] index=145 path=/usr/local/Cellar/go/1.11.5/libexec/src/reflect/asm_amd64.s
# [ ] index=146 path=/usr/local/Cellar/go/1.11.5/libexec/src/fmt/format.go
# [ ] index=147 path=/usr/local/Cellar/go/1.11.5/libexec/src/fmt/print.go
# [ ] index=148 path=/usr/local/Cellar/go/1.11.5/libexec/src/fmt/scan.go
# [ ] index=149 path=/Users/remco/Projects/sans/test.go
